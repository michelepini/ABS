# %%
import pandas as pd
import os
from google.colab import drive

drive.mount("/content/drive", force_remount=True)
data_path = "/content/drive/My Drive/Tesi/Esportazioni Dataset"
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel (data_path + '/20200416_1300_oil_analyses.xlsx')
df.to_csv("20200416_1300_EXPORT_ANALYSIS.csv", index=False)
